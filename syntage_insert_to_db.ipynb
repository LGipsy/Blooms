# %% [markdown]
# # Insert historical Syntage data to DB
#
# This notebook reads data from the Syntage API and... Then, it creates a table within a designated Postgres database and inserts the newest data.

# %%
# Import libraries

import datetime
import pprint
import numpy as np
import os
import pandas as pd
import pytz
import sqlalchemy
from IPython.display import display, HTML
from urllib.parse import quote_plus
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## API call to pull data for all entities

# %%
import http.client

SYNTAGE_API_KEY = os.getenv('SYNTAGE_API_KEY')

conn = http.client.HTTPSConnection("api.syntage.com")
payload = ''
headers = {
  'Accept': 'application/ld+json',
  'X-API-Key': SYNTAGE_API_KEY
}
conn.request("GET", "/entities?order%5BcreatedAt%5D=desc&itemsPerPage=1000", payload, headers)
res = conn.getresponse()
data = res.read()
pprint.pp(data.decode("utf-8"))
# Out:
# ('{"@context":"\\/contexts\\/Link","@id":"\\/entities","@type":"hydra:Collection","hydra:totalItems":21,"hydra:member":[{"@id":"\\/entities\\/9d2ac062-742c-4942-b7a7-8e9dbf5ca9cd","@type":"Link","id":"9d2ac062-742c-4942-b7a7-8e9dbf5ca9cd","type":"company","name":"AGRITEC '
#  'DEL '
#  'CENTRO","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/ACS921021HJ2","@type":"Taxpayer","id":"ACS921021HJ2","personType":"legal","registrationDate":"1992-10-21 '
#  '00:00:00","name":"AGRITEC DEL CENTRO","createdAt":"2024-05-08 '
#  '20:22:40","updatedAt":"2024-10-04 '
#  '19:17:14"},"credential":{"@id":"\\/credentials\\/9d2ac6b0-2454-4176-bce3-dbcc664f5c31","@type":"Credential","id":"9d2ac6b0-2454-4176-bce3-dbcc664f5c31","type":"ciec","rfc":"ACS921021HJ2","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-10-04 '
#  '19:34:36","updatedAt":"2024-10-04 19:34:48","name":"AGRITEC DEL '
#  'CENTRO"},"tags":[],"sample":false,"onboardingId":"9d2ac062-729c-47b5-8617-d6ebf0f6152a","createdAt":"2024-10-04 '
#  '19:16:58","updatedAt":"2024-10-04 '
#  '19:34:49"},{"@id":"\\/entities\\/9d149df8-e479-4fef-b2c8-f8a9eb7ab511","@type":"Link","id":"9d149df8-e479-4fef-b2c8-f8a9eb7ab511","type":"company","name":"SOCIEDAD '
#  'DE PRODUCCION AGRICOLA '
#  'MONTICAL","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/PAM060927VD1","@type":"Taxpayer","id":"PAM060927VD1","personType":"legal","registrationDate":"2006-09-27 '
#  '00:00:00","name":"SOCIEDAD DE PRODUCCION AGRICOLA '
#  'MONTICAL","createdAt":"2024-05-08 16:35:44","updatedAt":"2024-09-23 '
#  '19:14:23"},"credential":{"@id":"\\/credentials\\/9d149ded-cc51-4c64-a493-2bfc941bf527","@type":"Credential","id":"9d149ded-cc51-4c64-a493-2bfc941bf527","type":"ciec","rfc":"PAM060927VD1","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-09-23 '
#  '19:12:25","updatedAt":"2024-09-23 19:12:32","name":"SOCIEDAD DE PRODUCCION '
#  'AGRICOLA '
#  'MONTICAL"},"tags":[],"sample":false,"onboardingId":"9d149df8-e28c-4898-9943-6e145b27f904","createdAt":"2024-09-23 '
#  '19:12:32","updatedAt":"2024-09-23 '
#  '19:14:23"},{"@id":"\\/entities\\/9cf889a1-4cfc-4afb-a357-6ccf2a444837","@type":"Link","id":"9cf889a1-4cfc-4afb-a357-6ccf2a444837","type":"company","name":"JALAPEÑOS '
#  'Y '
#  'SERRANOS","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/JSS970306EW1","@type":"Taxpayer","id":"JSS970306EW1","personType":"legal","registrationDate":"1997-03-06 '
#  '00:00:00","name":"JALAPEÑOS Y SERRANOS","createdAt":"2021-05-04 '
#  '18:56:09","updatedAt":"2024-09-09 '
#  '20:12:52"},"credential":{"@id":"\\/credentials\\/9cf8899d-8261-4da1-a1fd-4ae259fd7ea5","@type":"Credential","id":"9cf8899d-8261-4da1-a1fd-4ae259fd7ea5","type":"ciec","rfc":"JSS970306EW1","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-09-09 '
#  '20:12:26","updatedAt":"2024-09-09 20:12:28","name":"JALAPEÑOS Y '
#  'SERRANOS"},"tags":[],"sample":false,"onboardingId":"9cf889a1-4b6d-4bd2-8047-592cad27afb9","createdAt":"2024-09-09 '
#  '20:12:28","updatedAt":"2024-09-09 '
#  '20:12:52"},{"@id":"\\/entities\\/9cf871d8-c400-4b5b-a729-621405ea6ca7","@type":"Link","id":"9cf871d8-c400-4b5b-a729-621405ea6ca7","type":"company","name":"VALNIC '
#  'FUSION","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/VFU21101495A","@type":"Taxpayer","id":"VFU21101495A","personType":"legal","registrationDate":"2021-10-14 '
#  '00:00:00","name":"VALNIC FUSION","createdAt":"2024-03-26 '
#  '20:59:27","updatedAt":"2024-03-26 '
#  '21:02:08"},"credential":{"@id":"\\/credentials\\/9cf871d5-ea3d-4122-905a-c63f07342af2","@type":"Credential","id":"9cf871d5-ea3d-4122-905a-c63f07342af2","type":"ciec","rfc":"VFU21101495A","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-09-09 '
#  '19:05:56","updatedAt":"2024-09-09 19:05:58","name":"VALNIC '
#  'FUSION"},"tags":[],"sample":false,"onboardingId":"9cf871d8-c2b7-41bf-8375-d5843e914ba1","createdAt":"2024-09-09 '
#  '19:05:58","updatedAt":"2024-09-09 '
#  '19:05:58"},{"@id":"\\/entities\\/9cea801b-ffa4-451a-b15b-41e193f71f5e","@type":"Link","id":"9cea801b-ffa4-451a-b15b-41e193f71f5e","type":"company","name":"CONTINENTAL '
#  'NUTRIMENTS","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/CNU180221A62","@type":"Taxpayer","id":"CNU180221A62","personType":"legal","registrationDate":"2018-02-21 '
#  '00:00:00","name":"CONTINENTAL NUTRIMENTS","createdAt":"2024-05-14 '
#  '21:55:30","updatedAt":"2024-09-02 '
#  '20:44:38"},"credential":{"@id":"\\/credentials\\/9cea8019-2eff-4793-b1f9-03ebff4f24fe","@type":"Credential","id":"9cea8019-2eff-4793-b1f9-03ebff4f24fe","type":"ciec","rfc":"CNU180221A62","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-09-02 '
#  '20:44:14","updatedAt":"2024-09-02 20:44:15","name":"CONTINENTAL '
#  'NUTRIMENTS"},"tags":[],"sample":false,"onboardingId":"9cea801b-fe8a-4b03-be59-adda889ff0a0","createdAt":"2024-09-02 '
#  '20:44:15","updatedAt":"2024-09-02 '
#  '20:44:38"},{"@id":"\\/entities\\/9ce06548-5538-4305-8924-8f5f6a2b1fba","@type":"Link","id":"9ce06548-5538-4305-8924-8f5f6a2b1fba","type":"company","name":"AGRICOLA '
#  'LA CUARTA '
#  'ESTACION","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/ACE150709S88","@type":"Taxpayer","id":"ACE150709S88","personType":"legal","registrationDate":"2015-07-09 '
#  '00:00:00","name":"AGRICOLA LA CUARTA ESTACION","createdAt":"2024-05-08 '
#  '14:26:46","updatedAt":"2024-08-09 '
#  '16:06:28"},"credential":{"@id":"\\/credentials\\/9ce06545-9c48-45a0-88cf-3947b9fc9339","@type":"Credential","id":"9ce06545-9c48-45a0-88cf-3947b9fc9339","type":"ciec","rfc":"ACE150709S88","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-28 '
#  '20:10:56","updatedAt":"2024-08-28 20:10:58","name":"AGRICOLA LA CUARTA '
#  'ESTACION"},"tags":[],"sample":false,"onboardingId":"9ce06548-53e1-4737-81d3-7e7d2b827639","createdAt":"2024-08-28 '
#  '20:10:58","updatedAt":"2024-08-28 '
#  '20:10:58"},{"@id":"\\/entities\\/9cc8947e-429d-44ed-9301-d84de094c759","@type":"Link","id":"9cc8947e-429d-44ed-9301-d84de094c759","type":"company","name":"DISTRIBUIDORA '
#  'DEL RANCHO '
#  'MEXICO","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/DRM150225E51","@type":"Taxpayer","id":"DRM150225E51","personType":"legal","registrationDate":"2015-02-25 '
#  '00:00:00","name":"DISTRIBUIDORA DEL RANCHO MEXICO","createdAt":"2020-08-05 '
#  '17:37:15","updatedAt":"2023-11-30 '
#  '02:50:55"},"credential":{"@id":"\\/credentials\\/9cc89471-fe7a-4f75-af4a-3434df133d27","@type":"Credential","id":"9cc89471-fe7a-4f75-af4a-3434df133d27","type":"ciec","rfc":"DRM150225E51","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-17 '
#  '00:02:58","updatedAt":"2024-08-17 00:08:45","name":"DISTRIBUIDORA DEL RANCHO '
#  'MEXICO"},"tags":[],"sample":false,"onboardingId":"9cc8947e-3f79-4322-b4bd-d7e199b0e161","createdAt":"2024-08-17 '
#  '00:03:06","updatedAt":"2024-08-17 '
#  '00:03:10"},{"@id":"\\/entities\\/9cabf4fc-1f0d-4b5e-aff5-373791518eed","@type":"Link","id":"9cabf4fc-1f0d-4b5e-aff5-373791518eed","type":"company","name":"AGRICOLA '
#  'SL","addedBy":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"owner":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"taxpayer":{"@id":"\\/taxpayers\\/ASL070709I37","@type":"Taxpayer","id":"ASL070709I37","personType":"legal","registrationDate":"2007-07-09 '
#  '00:00:00","name":"AGRICOLA SL","createdAt":"2022-11-04 '
#  '00:20:15","updatedAt":"2022-11-04 '
#  '00:20:15"},"credential":{"@id":"\\/credentials\\/9cabf64f-ef1c-4178-bb14-89ba81d3bea0","@type":"Credential","id":"9cabf64f-ef1c-4178-bb14-89ba81d3bea0","type":"ciec","rfc":"ASL070709I37","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-02 '
#  '18:37:37","updatedAt":"2024-08-02 18:38:16","name":"AGRICOLA '
#  'SL"},"tags":[],"sample":false,"onboardingId":"9cabf4fc-1c54-46f8-a22a-7dbcd5a344b8","createdAt":"2024-08-02 '
#  '18:33:55","updatedAt":"2024-08-02 '
#  '18:38:17"},{"@id":"\\/entities\\/9ca9b33f-095a-476d-bd8f-691212bdbd3c","@type":"Link","id":"9ca9b33f-095a-476d-bd8f-691212bdbd3c","type":"company","name":"CEDIS '
#  'HYFELD MEXICO SPR DE RL DE '
#  'CV","addedBy":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"owner":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"taxpayer":{"@id":"\\/taxpayers\\/CHM2201249Z2","@type":"Taxpayer","id":"CHM2201249Z2","personType":"legal","registrationDate":"2022-01-24 '
#  '00:00:00","name":"CEDIS HYFELD MEXICO SPR DE RL DE '
#  'CV","createdAt":"2024-05-19 14:27:40","updatedAt":"2024-05-19 '
#  '14:27:40"},"credential":null,"tags":[],"sample":false,"onboardingId":"9ca9b33f-0718-4811-b5ae-b44bae2bce0e","createdAt":"2024-08-01 '
#  '15:38:26","updatedAt":"2024-08-01 '
#  '15:38:26"},{"@id":"\\/entities\\/9ca9b2de-0138-442e-86f7-39b8151c93e9","@type":"Link","id":"9ca9b2de-0138-442e-86f7-39b8151c93e9","type":"company","name":"GRUPO '
#  'MIFA \\u0026 '
#  'ASC","addedBy":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"owner":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"taxpayer":{"@id":"\\/taxpayers\\/GMA180921GI3","@type":"Taxpayer","id":"GMA180921GI3","personType":"legal","registrationDate":"2018-09-21 '
#  '00:00:00","name":"GRUPO MIFA \\u0026 ASC","createdAt":"2022-10-04 '
#  '21:23:48","updatedAt":"2022-10-04 '
#  '21:23:48"},"credential":{"@id":"\\/credentials\\/9cea3e3d-fd24-4ffb-88c8-4675ffecc4b0","@type":"Credential","id":"9cea3e3d-fd24-4ffb-88c8-4675ffecc4b0","type":"ciec","rfc":"GMA180921GI3","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-09-02 '
#  '17:40:05","updatedAt":"2024-09-02 17:40:09","name":"GRUPO MIFA \\u0026 '
#  'ASC"},"tags":[],"sample":false,"onboardingId":"9ca9b2dd-ff51-41ed-a934-5f7263d925b8","createdAt":"2024-08-01 '
#  '15:37:22","updatedAt":"2024-09-02 '
#  '17:40:09"},{"@id":"\\/entities\\/9ca9b15b-f73d-4f19-b099-3b9e5f0db23f","@type":"Link","id":"9ca9b15b-f73d-4f19-b099-3b9e5f0db23f","type":"company","name":"AGRICOLA '
#  'FH","addedBy":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"owner":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"taxpayer":{"@id":"\\/taxpayers\\/AFH171011LH8","@type":"Taxpayer","id":"AFH171011LH8","personType":"legal","registrationDate":"2017-10-11 '
#  '00:00:00","name":"AGRICOLA FH","createdAt":"2020-11-27 '
#  '18:23:36","updatedAt":"2020-11-27 '
#  '18:23:36"},"credential":{"@id":"\\/credentials\\/9caa8048-2a0d-4bc9-9d0d-d1d1496777d2","@type":"Credential","id":"9caa8048-2a0d-4bc9-9d0d-d1d1496777d2","type":"ciec","rfc":"AFH171011LH8","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-02 '
#  '01:11:45","updatedAt":"2024-08-02 01:12:04","name":"AGRICOLA '
#  'FH"},"tags":[],"sample":false,"onboardingId":"9ca9b15b-f5a4-4530-b2ab-cde3de03c7f3","createdAt":"2024-08-01 '
#  '15:33:10","updatedAt":"2024-08-02 '
#  '01:12:04"},{"@id":"\\/entities\\/9ca9b0f1-f06a-4529-81d3-129cfad4ce48","@type":"Link","id":"9ca9b0f1-f06a-4529-81d3-129cfad4ce48","type":"company","name":"AREEM '
#  'AGRICOLA","addedBy":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"owner":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"taxpayer":{"@id":"\\/taxpayers\\/AAG1810096E1","@type":"Taxpayer","id":"AAG1810096E1","personType":"legal","registrationDate":"2018-10-09 '
#  '00:00:00","name":"AREEM AGRICOLA","createdAt":"2024-05-19 '
#  '16:16:29","updatedAt":"2024-08-06 '
#  '17:13:11"},"credential":{"@id":"\\/credentials\\/9cb3e372-31b2-48f5-ad72-9910ccff6615","@type":"Credential","id":"9cb3e372-31b2-48f5-ad72-9910ccff6615","type":"ciec","rfc":"AAG1810096E1","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-06 '
#  '17:11:29","updatedAt":"2024-08-06 17:11:42","name":"AREEM '
#  'AGRICOLA"},"tags":[],"sample":false,"onboardingId":"9ca9b0f1-eed9-4b77-bfa3-d9f3b647a04c","createdAt":"2024-08-01 '
#  '15:32:00","updatedAt":"2024-08-06 '
#  '17:13:11"},{"@id":"\\/entities\\/9ca9ad50-c64a-4e6f-9d0d-9a2bd489c3c3","@type":"Link","id":"9ca9ad50-c64a-4e6f-9d0d-9a2bd489c3c3","type":"company","name":"CEBOLLA '
#  'HAVILA","addedBy":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"owner":{"@id":"\\/users\\/9b2bb4ba-da96-4881-bd23-588ba6b54b1b","@type":"User","id":"9b2bb4ba-da96-4881-bd23-588ba6b54b1b","firstName":"Francisco '
#  '","lastName":"Mere","email":"paco@blooms.com.mx","locale":"es_MX","organization":"\\/organizations\\/9b2bb4ba-dc09-4100-8690-01a8ac40f1c2","activatedAt":"2024-01-24 '
#  '18:16:50","enabled":true,"roles":["ROLE_USER","ROLE_ADMIN","ROLE_CAN_CREATE_EXTRACTIONS","ROLE_CAN_CREATE_BIL_EXTRACTIONS","ROLE_CAN_CREATE_BDC_EXTRACTIONS"],"role":"general_director","otherRole":null,"eventNotifications":{"link.created":true,"extraction.first_time_completed":true},"deletedAt":null,"createdAt":"2024-01-24 '
#  '18:16:20","updatedAt":"2024-07-25 15:16:44","fullName":"Francisco  '
#  'Mere"},"taxpayer":{"@id":"\\/taxpayers\\/CHA160423NA7","@type":"Taxpayer","id":"CHA160423NA7","personType":"legal","registrationDate":"2016-04-23 '
#  '00:00:00","name":"CEBOLLA HAVILA","createdAt":"2023-06-19 '
#  '19:12:00","updatedAt":"2024-08-01 '
#  '16:31:50"},"credential":{"@id":"\\/credentials\\/9ca9b6ae-efba-4453-9c97-20ab629eb49b","@type":"Credential","id":"9ca9b6ae-efba-4453-9c97-20ab629eb49b","type":"ciec","rfc":"CHA160423NA7","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-01 '
#  '15:48:03","updatedAt":"2024-08-01 15:48:37","name":"CEBOLLA '
#  'HAVILA"},"tags":[],"sample":false,"onboardingId":"9ca9ad50-c3d6-435d-8e18-50976dde2dc0","createdAt":"2024-08-01 '
#  '15:21:51","updatedAt":"2024-08-01 '
#  '16:31:50"},{"@id":"\\/entities\\/9c89d389-5228-4905-8759-eb7e57fd0c9e","@type":"Link","id":"9c89d389-5228-4905-8759-eb7e57fd0c9e","type":"company","name":"INTEBAJ","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/INT091216VC6","@type":"Taxpayer","id":"INT091216VC6","personType":"legal","registrationDate":"2009-12-16 '
#  '00:00:00","name":"INTEBAJ","createdAt":"2022-03-24 '
#  '17:34:50","updatedAt":"2022-03-24 '
#  '17:37:54"},"credential":{"@id":"\\/credentials\\/9c89d599-7c55-4fcd-84b0-0ea37bcc7929","@type":"Credential","id":"9c89d599-7c55-4fcd-84b0-0ea37bcc7929","type":"ciec","rfc":"INT091216VC6","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-07-16 '
#  '19:28:00","updatedAt":"2024-07-16 '
#  '19:28:34","name":"INTEBAJ"},"tags":[],"sample":false,"onboardingId":"9c89d389-5118-4733-9738-6ddf5cdfd2e1","createdAt":"2024-07-16 '
#  '19:22:14","updatedAt":"2024-07-16 '
#  '19:28:34"},{"@id":"\\/entities\\/9c7ba709-fe4a-443f-b5c1-eff4578a12e2","@type":"Link","id":"9c7ba709-fe4a-443f-b5c1-eff4578a12e2","type":"company","name":"AGRICOLA '
#  'DEL '
#  'RANCHO","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/ARA011003DR2","@type":"Taxpayer","id":"ARA011003DR2","personType":"legal","registrationDate":"2001-10-03 '
#  '00:00:00","name":"AGRICOLA DEL RANCHO","createdAt":"2024-05-08 '
#  '17:38:57","updatedAt":"2024-07-09 '
#  '18:16:47"},"credential":{"@id":"\\/credentials\\/9c7ba6e1-ff0b-4da9-8462-5038a09d5635","@type":"Credential","id":"9c7ba6e1-ff0b-4da9-8462-5038a09d5635","type":"ciec","rfc":"ARA011003DR2","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-07-09 '
#  '18:15:47","updatedAt":"2024-07-09 18:16:13","name":"AGRICOLA DEL '
#  'RANCHO"},"tags":[],"sample":false,"onboardingId":"9c7ba709-fca8-435b-9e3f-2eaaf767341f","createdAt":"2024-07-09 '
#  '18:16:13","updatedAt":"2024-07-09 '
#  '18:16:47"},{"@id":"\\/entities\\/9c7973b4-88b0-4e07-8d65-f33f78bd03c5","@type":"Link","id":"9c7973b4-88b0-4e07-8d65-f33f78bd03c5","type":"company","name":"SPLENDID '
#  'FARMS","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/SFA1909258A6","@type":"Taxpayer","id":"SFA1909258A6","personType":"legal","registrationDate":"2019-09-25 '
#  '00:00:00","name":"SPLENDID FARMS","createdAt":"2022-11-18 '
#  '00:37:35","updatedAt":"2022-11-18 '
#  '00:37:35"},"credential":{"@id":"\\/credentials\\/9c79739b-d219-4ddc-8165-97b351a9e59d","@type":"Credential","id":"9c79739b-d219-4ddc-8165-97b351a9e59d","type":"ciec","rfc":"SFA1909258A6","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-07-08 '
#  '16:00:45","updatedAt":"2024-07-08 16:01:01","name":"SPLENDID '
#  'FARMS"},"tags":[],"sample":false,"onboardingId":"9c7973b4-760f-42ab-9bd4-c3264224c23a","createdAt":"2024-07-08 '
#  '16:01:01","updatedAt":"2024-07-08 '
#  '16:01:01"},{"@id":"\\/entities\\/9c73d05f-2acc-4cd5-9f92-f86b72c6882a","@type":"Link","id":"9c73d05f-2acc-4cd5-9f92-f86b72c6882a","type":"company","name":"GRUPO '
#  'VALROCH","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/GVA110303PB4","@type":"Taxpayer","id":"GVA110303PB4","personType":"legal","registrationDate":"2011-03-03 '
#  '00:00:00","name":"GRUPO VALROCH","createdAt":"2022-02-16 '
#  '16:55:13","updatedAt":"2023-11-30 '
#  '03:09:01"},"credential":{"@id":"\\/credentials\\/9c73d04a-f315-46f0-a1d4-c7b0ec770207","@type":"Credential","id":"9c73d04a-f315-46f0-a1d4-c7b0ec770207","type":"ciec","rfc":"GVA110303PB4","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-07-05 '
#  '20:44:57","updatedAt":"2024-07-05 20:45:10","name":"GRUPO '
#  'VALROCH"},"tags":[],"sample":false,"onboardingId":"9c73d05f-293c-4cb0-bb02-d840a15f1237","createdAt":"2024-07-05 '
#  '20:45:10","updatedAt":"2024-07-05 '
#  '20:45:10"},{"@id":"\\/entities\\/9c016ba0-ed00-4011-8b91-5c4d1a49108f","@type":"Link","id":"9c016ba0-ed00-4011-8b91-5c4d1a49108f","type":"company","name":"UELLBEE '
#  'TECHNOLOGIES","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/UTE1910213U0","@type":"Taxpayer","id":"UTE1910213U0","personType":"legal","registrationDate":"2019-10-21 '
#  '00:00:00","name":"UELLBEE TECHNOLOGIES","createdAt":"2022-04-18 '
#  '18:20:17","updatedAt":"2022-04-18 '
#  '18:20:17"},"credential":{"@id":"\\/credentials\\/9cbff116-85b2-479d-8070-5c88af768c22","@type":"Credential","id":"9cbff116-85b2-479d-8070-5c88af768c22","type":"ciec","rfc":"UTE1910213U0","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-08-12 '
#  '16:59:34","updatedAt":"2024-08-12 16:59:57","name":"UELLBEE '
#  'TECHNOLOGIES"},"tags":[],"sample":false,"onboardingId":"9c016ba0-eac9-4beb-b7c7-cd57bc2187eb","createdAt":"2024-05-09 '
#  '23:59:06","updatedAt":"2024-08-12 '
#  '16:59:57"},{"@id":"\\/entities\\/9bfab18d-f5fc-4c8c-8f7f-81d781769114","@type":"Link","id":"9bfab18d-f5fc-4c8c-8f7f-81d781769114","type":"company","name":"IMPAP '
#  'SERVICIOS '
#  'COMERCIALES","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/ISC150506UL1","@type":"Taxpayer","id":"ISC150506UL1","personType":"legal","registrationDate":"2015-05-06 '
#  '00:00:00","name":"IMPAP SERVICIOS COMERCIALES","createdAt":"2022-04-08 '
#  '20:58:06","updatedAt":"2024-05-06 '
#  '15:45:20"},"credential":{"@id":"\\/credentials\\/9d2d04bc-7306-468b-8514-d5a2ec2406ed","@type":"Credential","id":"9d2d04bc-7306-468b-8514-d5a2ec2406ed","type":"ciec","rfc":"ISC150506UL1","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-10-05 '
#  '22:19:45","updatedAt":"2024-10-05 22:21:04","name":"IMPAP SERVICIOS '
#  'COMERCIALES"},"tags":[],"sample":false,"onboardingId":"9bfab18d-f3ec-4580-ba01-11458ff127b2","createdAt":"2024-05-06 '
#  '15:43:50","updatedAt":"2024-10-05 '
#  '22:21:04"},{"@id":"\\/entities\\/9b73f4d0-a563-42ef-bc72-d18ad02f02d6","@type":"Link","id":"9b73f4d0-a563-42ef-bc72-d18ad02f02d6","type":"company","name":"Sociedad '
#  'Yáñez S.A.B. (Ejemplo '
#  '#1)","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/EAD180801SU3","@type":"Taxpayer","id":"EAD180801SU3","personType":"legal","registrationDate":"2018-08-01 '
#  '00:00:00","name":"Sociedad Yáñez S.A.B. (Ejemplo '
#  '#1)","createdAt":"2023-08-22 17:00:27","updatedAt":"2023-08-22 '
#  '17:00:27"},"credential":null,"tags":[],"sample":true,"onboardingId":"9bd45c46-b1f2-4266-bc14-0485a2707e11","createdAt":"2024-02-29 '
#  '16:15:08","updatedAt":"2024-02-29 '
#  '16:15:08"},{"@id":"\\/entities\\/9b3a4173-9213-4475-b305-306d6b30bc22","@type":"Link","id":"9b3a4173-9213-4475-b305-306d6b30bc22","type":"company","name":"ACEITES '
#  'SUSTENTABLES DE '
#  'PALMA","addedBy":null,"owner":null,"taxpayer":{"@id":"\\/taxpayers\\/ASP140623IP1","@type":"Taxpayer","id":"ASP140623IP1","personType":"legal","registrationDate":"2014-06-23 '
#  '00:00:00","name":"ACEITES SUSTENTABLES DE PALMA","createdAt":"2023-12-19 '
#  '19:29:22","updatedAt":"2023-12-19 '
#  '19:32:22"},"credential":{"@id":"\\/credentials\\/9bfb197f-3f99-477a-888c-e4a09bec6407","@type":"Credential","id":"9bfb197f-3f99-477a-888c-e4a09bec6407","type":"ciec","rfc":"ASP140623IP1","status":"valid","metadata":[],"extraction":null,"createdAt":"2024-05-06 '
#  '20:34:28","updatedAt":"2024-05-06 20:34:39","name":"ACEITES SUSTENTABLES DE '
#  'PALMA"},"tags":[{"@id":"\\/link-tags\\/9b481cad-76f1-4a2e-91f5-a9c173005511","@type":"LinkTag","id":"9b481cad-76f1-4a2e-91f5-a9c173005511","name":"Grupos '
#  'de contribuyentes: Default","createdAt":"2024-02-07 '
#  '21:09:38","updatedAt":"2024-02-07 '
#  '21:09:38"}],"sample":false,"onboardingId":"9bd45c46-8bd6-4b28-bdea-bef65d544476","createdAt":"2024-01-31 '
#  '23:51:25","updatedAt":"2024-05-06 '
#  '20:34:40"}],"hydra:view":{"@id":"\\/entities?itemsPerPage=1000\\u0026order%5BcreatedAt%5D=desc","@type":"hydra:PartialCollectionView"},"hydra:search":{"@type":"hydra:IriTemplate","hydra:template":"\\/entities{?properties[],id,id[],taxpayer.id,taxpayer.name,taxpayer.personType,taxpayer.personType[],credential.status,credential.status[],tags.name,type,type[],name,credential,credential[],order[id],order[createdAt],order[updatedAt],order[taxpayer.id],id[between],id[gt],id[gte],id[lt],id[lte],taxpayer.registrationDate[before],taxpayer.registrationDate[strictly_before],taxpayer.registrationDate[after],taxpayer.registrationDate[strictly_after],taxpayer,taxpayer[],createdAt[before],createdAt[strictly_before],createdAt[after],createdAt[strictly_after],updatedAt[before],updatedAt[strictly_before],updatedAt[after],updatedAt[strictly_after]}","hydra:variableRepresentation":"BasicRepresentation","hydra:mapping":[{"@type":"IriTemplateMapping","variable":"properties[]","property":null,"required":false},{"@type":"IriTemplateMapping","variable":"id","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"id[]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.id","property":"taxpayer.id","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.name","property":"taxpayer.name","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.personType","property":"taxpayer.personType","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.personType[]","property":"taxpayer.personType","required":false},{"@type":"IriTemplateMapping","variable":"credential.status","property":"credential.status","required":false},{"@type":"IriTemplateMapping","variable":"credential.status[]","property":"credential.status","required":false},{"@type":"IriTemplateMapping","variable":"tags.name","property":"tags.name","required":false},{"@type":"IriTemplateMapping","variable":"type","property":"type","required":false},{"@type":"IriTemplateMapping","variable":"type[]","property":"type","required":false},{"@type":"IriTemplateMapping","variable":"name","property":"name","required":false},{"@type":"IriTemplateMapping","variable":"credential","property":"credential","required":false},{"@type":"IriTemplateMapping","variable":"credential[]","property":"credential","required":false},{"@type":"IriTemplateMapping","variable":"order[id]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"order[createdAt]","property":"createdAt","required":false},{"@type":"IriTemplateMapping","variable":"order[updatedAt]","property":"updatedAt","required":false},{"@type":"IriTemplateMapping","variable":"order[taxpayer.id]","property":"taxpayer.id","required":false},{"@type":"IriTemplateMapping","variable":"id[between]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"id[gt]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"id[gte]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"id[lt]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"id[lte]","property":"id","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.registrationDate[before]","property":"taxpayer.registrationDate","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.registrationDate[strictly_before]","property":"taxpayer.registrationDate","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.registrationDate[after]","property":"taxpayer.registrationDate","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer.registrationDate[strictly_after]","property":"taxpayer.registrationDate","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer","property":"taxpayer","required":false},{"@type":"IriTemplateMapping","variable":"taxpayer[]","property":"taxpayer","required":false},{"@type":"IriTemplateMapping","variable":"createdAt[before]","property":"created ...

# %%
print (SYNTAGE_API_KEY)
# Out:
# 03519f3245652ddb6dfc87391b8fdca1

# %%
import json
import psycopg2d
from psycopg2 import sql


DB_HOST = os.getenv('DB_HOST')
DB_PORT = os.getenv('DB_PORT')
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')

# Establish connection to PostgreSQL
def connect_db():
    conn = psycopg2.connect(
        host=DB_HOST,
        port=DB_PORT,
        database=DB_NAME,
        user=DB_USER,
        password=DB_PASSWORD
    )
    return conn


def insert_into_entities(cursor, entity):
    insert_query = """
        INSERT INTO entities (
            id, type, name, added_by, owner, taxpayer_id, taxpayer_person_type, 
            taxpayer_registration_date, taxpayer_name, taxpayer_created_at, 
            taxpayer_updated_at, credential_id, credential_type, credential_rfc, 
            credential_status, credential_created_at, credential_updated_at, 
            tags, sample, onboarding_id, created_at, updated_at
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING;
    """
    
    taxpayer = entity.get('taxpayer', {})
    credential = entity.get('credential', {})
    
    cursor.execute(insert_query, (
        entity.get('id'),
        entity.get('type'),
        entity.get('name'),
        json.dumps(entity.get('addedBy')) if entity.get('addedBy') else None,
        json.dumps(entity.get('owner')) if entity.get('owner') else None,
        taxpayer.get('id'),
        taxpayer.get('personType'),
        taxpayer.get('registrationDate'),
        taxpayer.get('name'),
        taxpayer.get('createdAt'),
        taxpayer.get('updatedAt'),
        credential.get('id'),
        credential.get('type'),
        credential.get('rfc'),
        credential.get('status'),
        credential.get('createdAt'),
        credential.get('updatedAt'),
        json.dumps(entity.get('tags', [])),
        entity.get('sample'),
        entity.get('onboardingId'),
        entity.get('createdAt'),
        entity.get('updatedAt')
    ))


# Insert data into the PostgreSQL table
def insert_into_entities(cursor, entity):
    insert_query = """
        INSERT INTO entities (
            id, type, name, added_by, owner, taxpayer_id, taxpayer_person_type, 
            taxpayer_registration_date, taxpayer_name, taxpayer_created_at, 
            taxpayer_updated_at, credential_id, credential_type, credential_rfc, 
            credential_status, credential_created_at, credential_updated_at, 
            tags, sample, onboarding_id, created_at, updated_at
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING;
    """
    
    cursor.execute(insert_query, (
        entity.get('id'),
        entity.get('type'),
        entity.get('name'),
        json.dumps(entity.get('addedBy')),
        json.dumps(entity.get('owner')),
        entity['taxpayer']['id'],
        entity['taxpayer']['personType'],
        entity['taxpayer']['registrationDate'],
        entity['taxpayer']['name'],
        entity['taxpayer']['createdAt'],
        entity['taxpayer']['updatedAt'],
        entity['credential']['id'],
        entity['credential']['type'],
        entity['credential']['rfc'],
        entity['credential']['status'],
        entity['credential']['createdAt'],
        entity['credential']['updatedAt'],
        json.dumps(entity.get('tags', [])),
        entity.get('sample'),
        entity.get('onboardingId'),
        entity.get('createdAt'),
        entity.get('updatedAt')
    ))

# Function to parse JSON and insert data into the database
def parse_and_insert(json_data):
    # Establish a connection and start transaction
    conn = connect_db()
    cursor = conn.cursor()

    # Loop through each entity in the JSON
    for entity in json_data['hydra:member']:
        insert_into_entities(cursor, entity)
    
    # Commit and close
    conn.commit()
    cursor.close()
    conn.close()

# Example usage
if __name__ == "__main__":
    # Load your JSON data here
    json_str = '''{...}'''  # Replace this with your JSON string
    json_data = json.loads(json_str)
    
    # Parse and insert data into the database
    parse_and_insert(json_data)

# %%
import json
import psycopg2
from psycopg2 import sql

# Establish connection to PostgreSQL


def connect_db():
    conn = psycopg2.connect(
        host="blooms-analytics-db.c5e4ooiayxfd.us-east-1.rds.amazonaws.com",
        database="analytics",
        user="blooms_writer",
        password="XNS7TEMceDMQCXH9EnpYdo"
    )
    return conn


def insert_into_entities(cursor, entity):
    insert_query = """
        INSERT INTO entities (
            id, type, name, added_by, owner, taxpayer_id, taxpayer_person_type, 
            taxpayer_registration_date, taxpayer_name, taxpayer_created_at, 
            taxpayer_updated_at, credential_id, credential_type, credential_rfc, 
            credential_status, credential_created_at, credential_updated_at, 
            tags, sample, onboarding_id, created_at, updated_at
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING;
    """

    taxpayer = entity.get('taxpayer', {})
    credential = entity.get('credential', {})

    cursor.execute(insert_query, (
        entity.get('id'),
        entity.get('type'),
        entity.get('name'),
        json.dumps(entity.get('addedBy')) if entity.get('addedBy') else None,
        json.dumps(entity.get('owner')) if entity.get('owner') else None,
        taxpayer.get('id'),
        taxpayer.get('personType'),
        taxpayer.get('registrationDate'),
        taxpayer.get('name'),
        taxpayer.get('createdAt'),
        taxpayer.get('updatedAt'),
        credential.get('id'),
        credential.get('type'),
        credential.get('rfc'),
        credential.get('status'),
        credential.get('createdAt'),
        credential.get('updatedAt'),
        json.dumps(entity.get('tags', [])),
        entity.get('sample'),
        entity.get('onboardingId'),
        entity.get('createdAt'),
        entity.get('updatedAt')
    ))



def insert_into_entities(cursor, entity):
    insert_query = """
        INSERT INTO entities (
            id, type, name, added_by, owner, taxpayer_id, taxpayer_person_type, 
            taxpayer_registration_date, taxpayer_name, taxpayer_created_at, 
            taxpayer_updated_at, credential_id, credential_type, credential_rfc, 
            credential_status, credential_created_at, credential_updated_at, 
            tags, sample, onboarding_id, created_at, updated_at
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (id) DO NOTHING;
    """

    taxpayer = entity.get('taxpayer', {})
    credential = entity.get('credential', {})

    cursor.execute(insert_query, (
        entity.get('id'),
        entity.get('type'),
        entity.get('name'),
        json.dumps(entity.get('addedBy')) if entity.get('addedBy') else None,
        json.dumps(entity.get('owner')) if entity.get('owner') else None,
        taxpayer.get('id'),
        taxpayer.get('personType'),
        taxpayer.get('registrationDate'),
        taxpayer.get('name'),
        taxpayer.get('createdAt'),
        taxpayer.get('updatedAt'),
        credential.get('id'),
        credential.get('type'),
        credential.get('rfc'),
        credential.get('status'),
        credential.get('createdAt'),
        credential.get('updatedAt'),
        json.dumps(entity.get('tags', [])),
        entity.get('sample'),
        entity.get('onboardingId'),
        entity.get('createdAt'),
        entity.get('updatedAt')
    ))

# Function to parse JSON and insert data into the database
def parse_and_insert(json_data):
    # Establish a connection and start transaction
    conn = connect_db()
    cursor = conn.cursor()

    # Loop through each entity in the JSON
    for entity in json_data['hydra:member']:
        insert_into_entities(cursor, entity)

    # Commit and close
    conn.commit()
    cursor.close()
    conn.close()


""" 
# Example usage
if __name__ == "__main__":
    # Load your JSON data here
    json_str = '''{...}'''  # Replace this with your JSON string
    json_data = json.loads(json_str)

    # Parse and insert data into the database
    parse_and_insert(json_data) """
# Out:
# ' \n# Example usage\nif __name__ == "__main__":\n    # Load your JSON data here\n    json_str = \'\'\'{...}\'\'\'  # Replace this with your JSON string\n    json_data = json.loads(json_str)\n\n    # Parse and insert data into the database\n    parse_and_insert(json_data) '

# %%
json_data = json.loads(data)

# Parse and insert data into the database
parse_and_insert(json_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 json_data = json.loads(data)
#       3 # Parse and insert data into the database
# ----> 4 parse_and_insert(json_data)
#
# Cell In[4], line 108, in parse_and_insert(json_data)
#     106 # Loop through each entity in the JSON
#     107 for entity in json_data['hydra:member']:
# --> 108     insert_into_entities(cursor, entity)
#     110 # Commit and close
#     111 conn.commit()
#
# Cell In[4], line 75, in insert_into_entities(cursor, entity)
#      72 taxpayer = entity.get('taxpayer', {})
#      73 credential = entity.get('credential', {})
# ---> 75 cursor.execute(insert_query, (
#      76     entity.get('id'),
#      77     entity.get('type'),
#      78     entity.get('name'),
#      79     json.dumps(entity.get('addedBy')) if entity.get('addedBy') else None,
#      80     json.dumps(entity.get('owner')) if entity.get('owner') else None,
#      81     taxpayer.get('id'),
#      82     taxpayer.get('personType'),
#      83     taxpayer.get('registrationDate'),
#      84     taxpayer.get('name'),
#      85     taxpayer.get('createdAt'),
#      86     taxpayer.get('updatedAt'),
#      87     credential.get('id'),
#      88     credential.get('type'),
#      89     credential.get('rfc'),
#      90     credential.get('status'),
#      91     credential.get('createdAt'),
#      92     credential.get('updatedAt'),
#      93     json.dumps(entity.get('tags', [])),
#      94     entity.get('sample'),
#      95     entity.get('onboardingId'),
#      96     entity.get('createdAt'),
#      97     entity.get('updatedAt')
#      98 ))
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# ### Code to parse json of entities

# %%
import json

def parse_json_to_dict(data):
    parsed_data = []

    # Iterate through each 'hydra:member' (company entry)
    for entity in data.get("hydra:member", []):
        company_dict = {
            "id": entity.get("id", None),
            "type": entity.get("type", None),
            "name": entity.get("name", None),
            "addedBy": {
                "id": entity.get("addedBy", {}).get("id", None),
                "firstName": entity.get("addedBy", {}).get("firstName", None),
                "lastName": entity.get("addedBy", {}).get("lastName", None),
                "email": entity.get("addedBy", {}).get("email", None),
            } if entity.get("addedBy") else None,
            "owner": {
                "id": entity.get("owner", {}).get("id", None),
                "firstName": entity.get("owner", {}).get("firstName", None),
                "lastName": entity.get("owner", {}).get("lastName", None),
                "email": entity.get("owner", {}).get("email", None),
            } if entity.get("owner") else None,
            "taxpayer": {
                "id": entity.get("taxpayer", {}).get("id", None),
                "personType": entity.get("taxpayer", {}).get("personType", None),
                "registrationDate": entity.get("taxpayer", {}).get("registrationDate", None),
                "name": entity.get("taxpayer", {}).get("name", None),
                "createdAt": entity.get("taxpayer", {}).get("createdAt", None),
                "updatedAt": entity.get("taxpayer", {}).get("updatedAt", None),
            } if entity.get("taxpayer") else None,
            "credential": {
                "id": entity.get("credential", {}).get("id", None),
                "type": entity.get("credential", {}).get("type", None),
                "rfc": entity.get("credential", {}).get("rfc", None),
                "status": entity.get("credential", {}).get("status", None),
                "createdAt": entity.get("credential", {}).get("createdAt", None),
                "updatedAt": entity.get("credential", {}).get("updatedAt", None),
            } if entity.get("credential") else None,
            "onboardingId": entity.get("onboardingId", None),
            "createdAt": entity.get("createdAt", None),
            "updatedAt": entity.get("updatedAt", None),
            "sample": entity.get("sample", None),
            "tags": [tag.get("name", None) for tag in entity.get("tags", [])]
        }
        parsed_data.append(company_dict)

    return parsed_data

# Example usage:
# Assuming your JSON is stored as a string in the variable 'json_string'
# data = json.loads(json_string)
# result = parse_json_to_dict(data)

# %%
dd = parse_json_to_dict(json.loads(data))

# %%
dd
# Out:
# [{'id': '9d2ac062-742c-4942-b7a7-8e9dbf5ca9cd',
#   'type': 'company',
#   'name': 'AGRITEC DEL CENTRO',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'ACS921021HJ2',
#    'personType': 'legal',
#    'registrationDate': '1992-10-21 00:00:00',
#    'name': 'AGRITEC DEL CENTRO',
#    'createdAt': '2024-05-08 20:22:40',
#    'updatedAt': '2024-10-04 19:17:14'},
#   'credential': {'id': '9d2ac6b0-2454-4176-bce3-dbcc664f5c31',
#    'type': 'ciec',
#    'rfc': 'ACS921021HJ2',
#    'status': 'valid',
#    'createdAt': '2024-10-04 19:34:36',
#    'updatedAt': '2024-10-04 19:34:48'},
#   'onboardingId': '9d2ac062-729c-47b5-8617-d6ebf0f6152a',
#   'createdAt': '2024-10-04 19:16:58',
#   'updatedAt': '2024-10-04 19:34:49',
#   'sample': False,
#   'tags': []},
#  {'id': '9d149df8-e479-4fef-b2c8-f8a9eb7ab511',
#   'type': 'company',
#   'name': 'SOCIEDAD DE PRODUCCION AGRICOLA MONTICAL',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'PAM060927VD1',
#    'personType': 'legal',
#    'registrationDate': '2006-09-27 00:00:00',
#    'name': 'SOCIEDAD DE PRODUCCION AGRICOLA MONTICAL',
#    'createdAt': '2024-05-08 16:35:44',
#    'updatedAt': '2024-09-23 19:14:23'},
#   'credential': {'id': '9d149ded-cc51-4c64-a493-2bfc941bf527',
#    'type': 'ciec',
#    'rfc': 'PAM060927VD1',
#    'status': 'valid',
#    'createdAt': '2024-09-23 19:12:25',
#    'updatedAt': '2024-09-23 19:12:32'},
#   'onboardingId': '9d149df8-e28c-4898-9943-6e145b27f904',
#   'createdAt': '2024-09-23 19:12:32',
#   'updatedAt': '2024-09-23 19:14:23',
#   'sample': False,
#   'tags': []},
#  {'id': '9cf889a1-4cfc-4afb-a357-6ccf2a444837',
#   'type': 'company',
#   'name': 'JALAPEÑOS Y SERRANOS',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'JSS970306EW1',
#    'personType': 'legal',
#    'registrationDate': '1997-03-06 00:00:00',
#    'name': 'JALAPEÑOS Y SERRANOS',
#    'createdAt': '2021-05-04 18:56:09',
#    'updatedAt': '2024-09-09 20:12:52'},
#   'credential': {'id': '9cf8899d-8261-4da1-a1fd-4ae259fd7ea5',
#    'type': 'ciec',
#    'rfc': 'JSS970306EW1',
#    'status': 'valid',
#    'createdAt': '2024-09-09 20:12:26',
#    'updatedAt': '2024-09-09 20:12:28'},
#   'onboardingId': '9cf889a1-4b6d-4bd2-8047-592cad27afb9',
#   'createdAt': '2024-09-09 20:12:28',
#   'updatedAt': '2024-09-09 20:12:52',
#   'sample': False,
#   'tags': []},
#  {'id': '9cf871d8-c400-4b5b-a729-621405ea6ca7',
#   'type': 'company',
#   'name': 'VALNIC FUSION',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'VFU21101495A',
#    'personType': 'legal',
#    'registrationDate': '2021-10-14 00:00:00',
#    'name': 'VALNIC FUSION',
#    'createdAt': '2024-03-26 20:59:27',
#    'updatedAt': '2024-03-26 21:02:08'},
#   'credential': {'id': '9cf871d5-ea3d-4122-905a-c63f07342af2',
#    'type': 'ciec',
#    'rfc': 'VFU21101495A',
#    'status': 'valid',
#    'createdAt': '2024-09-09 19:05:56',
#    'updatedAt': '2024-09-09 19:05:58'},
#   'onboardingId': '9cf871d8-c2b7-41bf-8375-d5843e914ba1',
#   'createdAt': '2024-09-09 19:05:58',
#   'updatedAt': '2024-09-09 19:05:58',
#   'sample': False,
#   'tags': []},
#  {'id': '9cea801b-ffa4-451a-b15b-41e193f71f5e',
#   'type': 'company',
#   'name': 'CONTINENTAL NUTRIMENTS',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'CNU180221A62',
#    'personType': 'legal',
#    'registrationDate': '2018-02-21 00:00:00',
#    'name': 'CONTINENTAL NUTRIMENTS',
#    'createdAt': '2024-05-14 21:55:30',
#    'updatedAt': '2024-09-02 20:44:38'},
#   'credential': {'id': '9cea8019-2eff-4793-b1f9-03ebff4f24fe',
#    'type': 'ciec',
#    'rfc': 'CNU180221A62',
#    'status': 'valid',
#    'createdAt': '2024-09-02 20:44:14',
#    'updatedAt': '2024-09-02 20:44:15'},
#   'onboardingId': '9cea801b-fe8a-4b03-be59-adda889ff0a0',
#   'createdAt': '2024-09-02 20:44:15',
#   'updatedAt': '2024-09-02 20:44:38',
#   'sample': False,
#   'tags': []},
#  {'id': '9ce06548-5538-4305-8924-8f5f6a2b1fba',
#   'type': 'company',
#   'name': 'AGRICOLA LA CUARTA ESTACION',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'ACE150709S88',
#    'personType': 'legal',
#    'registrationDate': '2015-07-09 00:00:00',
#    'name': 'AGRICOLA LA CUARTA ESTACION',
#    'createdAt': '2024-05-08 14:26:46',
#    'updatedAt': '2024-08-09 16:06:28'},
#   'credential': {'id': '9ce06545-9c48-45a0-88cf-3947b9fc9339',
#    'type': 'ciec',
#    'rfc': 'ACE150709S88',
#    'status': 'valid',
#    'createdAt': '2024-08-28 20:10:56',
#    'updatedAt': '2024-08-28 20:10:58'},
#   'onboardingId': '9ce06548-53e1-4737-81d3-7e7d2b827639',
#   'createdAt': '2024-08-28 20:10:58',
#   'updatedAt': '2024-08-28 20:10:58',
#   'sample': False,
#   'tags': []},
#  {'id': '9cc8947e-429d-44ed-9301-d84de094c759',
#   'type': 'company',
#   'name': 'DISTRIBUIDORA DEL RANCHO MEXICO',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'DRM150225E51',
#    'personType': 'legal',
#    'registrationDate': '2015-02-25 00:00:00',
#    'name': 'DISTRIBUIDORA DEL RANCHO MEXICO',
#    'createdAt': '2020-08-05 17:37:15',
#    'updatedAt': '2023-11-30 02:50:55'},
#   'credential': {'id': '9cc89471-fe7a-4f75-af4a-3434df133d27',
#    'type': 'ciec',
#    'rfc': 'DRM150225E51',
#    'status': 'valid',
#    'createdAt': '2024-08-17 00:02:58',
#    'updatedAt': '2024-08-17 00:08:45'},
#   'onboardingId': '9cc8947e-3f79-4322-b4bd-d7e199b0e161',
#   'createdAt': '2024-08-17 00:03:06',
#   'updatedAt': '2024-08-17 00:03:10',
#   'sample': False,
#   'tags': []},
#  {'id': '9cabf4fc-1f0d-4b5e-aff5-373791518eed',
#   'type': 'company',
#   'name': 'AGRICOLA SL',
#   'addedBy': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'owner': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'taxpayer': {'id': 'ASL070709I37',
#    'personType': 'legal',
#    'registrationDate': '2007-07-09 00:00:00',
#    'name': 'AGRICOLA SL',
#    'createdAt': '2022-11-04 00:20:15',
#    'updatedAt': '2022-11-04 00:20:15'},
#   'credential': {'id': '9cabf64f-ef1c-4178-bb14-89ba81d3bea0',
#    'type': 'ciec',
#    'rfc': 'ASL070709I37',
#    'status': 'valid',
#    'createdAt': '2024-08-02 18:37:37',
#    'updatedAt': '2024-08-02 18:38:16'},
#   'onboardingId': '9cabf4fc-1c54-46f8-a22a-7dbcd5a344b8',
#   'createdAt': '2024-08-02 18:33:55',
#   'updatedAt': '2024-08-02 18:38:17',
#   'sample': False,
#   'tags': []},
#  {'id': '9ca9b33f-095a-476d-bd8f-691212bdbd3c',
#   'type': 'company',
#   'name': 'CEDIS HYFELD MEXICO SPR DE RL DE CV',
#   'addedBy': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'owner': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'taxpayer': {'id': 'CHM2201249Z2',
#    'personType': 'legal',
#    'registrationDate': '2022-01-24 00:00:00',
#    'name': 'CEDIS HYFELD MEXICO SPR DE RL DE CV',
#    'createdAt': '2024-05-19 14:27:40',
#    'updatedAt': '2024-05-19 14:27:40'},
#   'credential': None,
#   'onboardingId': '9ca9b33f-0718-4811-b5ae-b44bae2bce0e',
#   'createdAt': '2024-08-01 15:38:26',
#   'updatedAt': '2024-08-01 15:38:26',
#   'sample': False,
#   'tags': []},
#  {'id': '9ca9b2de-0138-442e-86f7-39b8151c93e9',
#   'type': 'company',
#   'name': 'GRUPO MIFA & ASC',
#   'addedBy': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'owner': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'taxpayer': {'id': 'GMA180921GI3',
#    'personType': 'legal',
#    'registrationDate': '2018-09-21 00:00:00',
#    'name': 'GRUPO MIFA & ASC',
#    'createdAt': '2022-10-04 21:23:48',
#    'updatedAt': '2022-10-04 21:23:48'},
#   'credential': {'id': '9cea3e3d-fd24-4ffb-88c8-4675ffecc4b0',
#    'type': 'ciec',
#    'rfc': 'GMA180921GI3',
#    'status': 'valid',
#    'createdAt': '2024-09-02 17:40:05',
#    'updatedAt': '2024-09-02 17:40:09'},
#   'onboardingId': '9ca9b2dd-ff51-41ed-a934-5f7263d925b8',
#   'createdAt': '2024-08-01 15:37:22',
#   'updatedAt': '2024-09-02 17:40:09',
#   'sample': False,
#   'tags': []},
#  {'id': '9ca9b15b-f73d-4f19-b099-3b9e5f0db23f',
#   'type': 'company',
#   'name': 'AGRICOLA FH',
#   'addedBy': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'owner': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'taxpayer': {'id': 'AFH171011LH8',
#    'personType': 'legal',
#    'registrationDate': '2017-10-11 00:00:00',
#    'name': 'AGRICOLA FH',
#    'createdAt': '2020-11-27 18:23:36',
#    'updatedAt': '2020-11-27 18:23:36'},
#   'credential': {'id': '9caa8048-2a0d-4bc9-9d0d-d1d1496777d2',
#    'type': 'ciec',
#    'rfc': 'AFH171011LH8',
#    'status': 'valid',
#    'createdAt': '2024-08-02 01:11:45',
#    'updatedAt': '2024-08-02 01:12:04'},
#   'onboardingId': '9ca9b15b-f5a4-4530-b2ab-cde3de03c7f3',
#   'createdAt': '2024-08-01 15:33:10',
#   'updatedAt': '2024-08-02 01:12:04',
#   'sample': False,
#   'tags': []},
#  {'id': '9ca9b0f1-f06a-4529-81d3-129cfad4ce48',
#   'type': 'company',
#   'name': 'AREEM AGRICOLA',
#   'addedBy': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'owner': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'taxpayer': {'id': 'AAG1810096E1',
#    'personType': 'legal',
#    'registrationDate': '2018-10-09 00:00:00',
#    'name': 'AREEM AGRICOLA',
#    'createdAt': '2024-05-19 16:16:29',
#    'updatedAt': '2024-08-06 17:13:11'},
#   'credential': {'id': '9cb3e372-31b2-48f5-ad72-9910ccff6615',
#    'type': 'ciec',
#    'rfc': 'AAG1810096E1',
#    'status': 'valid',
#    'createdAt': '2024-08-06 17:11:29',
#    'updatedAt': '2024-08-06 17:11:42'},
#   'onboardingId': '9ca9b0f1-eed9-4b77-bfa3-d9f3b647a04c',
#   'createdAt': '2024-08-01 15:32:00',
#   'updatedAt': '2024-08-06 17:13:11',
#   'sample': False,
#   'tags': []},
#  {'id': '9ca9ad50-c64a-4e6f-9d0d-9a2bd489c3c3',
#   'type': 'company',
#   'name': 'CEBOLLA HAVILA',
#   'addedBy': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'owner': {'id': '9b2bb4ba-da96-4881-bd23-588ba6b54b1b',
#    'firstName': 'Francisco ',
#    'lastName': 'Mere',
#    'email': 'paco@blooms.com.mx'},
#   'taxpayer': {'id': 'CHA160423NA7',
#    'personType': 'legal',
#    'registrationDate': '2016-04-23 00:00:00',
#    'name': 'CEBOLLA HAVILA',
#    'createdAt': '2023-06-19 19:12:00',
#    'updatedAt': '2024-08-01 16:31:50'},
#   'credential': {'id': '9ca9b6ae-efba-4453-9c97-20ab629eb49b',
#    'type': 'ciec',
#    'rfc': 'CHA160423NA7',
#    'status': 'valid',
#    'createdAt': '2024-08-01 15:48:03',
#    'updatedAt': '2024-08-01 15:48:37'},
#   'onboardingId': '9ca9ad50-c3d6-435d-8e18-50976dde2dc0',
#   'createdAt': '2024-08-01 15:21:51',
#   'updatedAt': '2024-08-01 16:31:50',
#   'sample': False,
#   'tags': []},
#  {'id': '9c89d389-5228-4905-8759-eb7e57fd0c9e',
#   'type': 'company',
#   'name': 'INTEBAJ',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'INT091216VC6',
#    'personType': 'legal',
#    'registrationDate': '2009-12-16 00:00:00',
#    'name': 'INTEBAJ',
#    'createdAt': '2022-03-24 17:34:50',
#    'updatedAt': '2022-03-24 17:37:54'},
#   'credential': {'id': '9c89d599-7c55-4fcd-84b0-0ea37bcc7929',
#    'type': 'ciec',
#    'rfc': 'INT091216VC6',
#    'status': 'valid',
#    'createdAt': '2024-07-16 19:28:00',
#    'updatedAt': '2024-07-16 19:28:34'},
#   'onboardingId': '9c89d389-5118-4733-9738-6ddf5cdfd2e1',
#   'createdAt': '2024-07-16 19:22:14',
#   'updatedAt': '2024-07-16 19:28:34',
#   'sample': False,
#   'tags': []},
#  {'id': '9c7ba709-fe4a-443f-b5c1-eff4578a12e2',
#   'type': 'company',
#   'name': 'AGRICOLA DEL RANCHO',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'ARA011003DR2',
#    'personType': 'legal',
#    'registrationDate': '2001-10-03 00:00:00',
#    'name': 'AGRICOLA DEL RANCHO',
#    'createdAt': '2024-05-08 17:38:57',
#    'updatedAt': '2024-07-09 18:16:47'},
#   'credential': {'id': '9c7ba6e1-ff0b-4da9-8462-5038a09d5635',
#    'type': 'ciec',
#    'rfc': 'ARA011003DR2',
#    'status': 'valid',
#    'createdAt': '2024-07-09 18:15:47',
#    'updatedAt': '2024-07-09 18:16:13'},
#   'onboardingId': '9c7ba709-fca8-435b-9e3f-2eaaf767341f',
#   'createdAt': '2024-07-09 18:16:13',
#   'updatedAt': '2024-07-09 18:16:47',
#   'sample': False,
#   'tags': []},
#  {'id': '9c7973b4-88b0-4e07-8d65-f33f78bd03c5',
#   'type': 'company',
#   'name': 'SPLENDID FARMS',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'SFA1909258A6',
#    'personType': 'legal',
#    'registrationDate': '2019-09-25 00:00:00',
#    'name': 'SPLENDID FARMS',
#    'createdAt': '2022-11-18 00:37:35',
#    'updatedAt': '2022-11-18 00:37:35'},
#   'credential': {'id': '9c79739b-d219-4ddc-8165-97b351a9e59d',
#    'type': 'ciec',
#    'rfc': 'SFA1909258A6',
#    'status': 'valid',
#    'createdAt': '2024-07-08 16:00:45',
#    'updatedAt': '2024-07-08 16:01:01'},
#   'onboardingId': '9c7973b4-760f-42ab-9bd4-c3264224c23a',
#   'createdAt': '2024-07-08 16:01:01',
#   'updatedAt': '2024-07-08 16:01:01',
#   'sample': False,
#   'tags': []},
#  {'id': '9c73d05f-2acc-4cd5-9f92-f86b72c6882a',
#   'type': 'company',
#   'name': 'GRUPO VALROCH',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'GVA110303PB4',
#    'personType': 'legal',
#    'registrationDate': '2011-03-03 00:00:00',
#    'name': 'GRUPO VALROCH',
#    'createdAt': '2022-02-16 16:55:13',
#    'updatedAt': '2023-11-30 03:09:01'},
#   'credential': {'id': '9c73d04a-f315-46f0-a1d4-c7b0ec770207',
#    'type': 'ciec',
#    'rfc': 'GVA110303PB4',
#    'status': 'valid',
#    'createdAt': '2024-07-05 20:44:57',
#    'updatedAt': '2024-07-05 20:45:10'},
#   'onboardingId': '9c73d05f-293c-4cb0-bb02-d840a15f1237',
#   'createdAt': '2024-07-05 20:45:10',
#   'updatedAt': '2024-07-05 20:45:10',
#   'sample': False,
#   'tags': []},
#  {'id': '9c016ba0-ed00-4011-8b91-5c4d1a49108f',
#   'type': 'company',
#   'name': 'UELLBEE TECHNOLOGIES',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'UTE1910213U0',
#    'personType': 'legal',
#    'registrationDate': '2019-10-21 00:00:00',
#    'name': 'UELLBEE TECHNOLOGIES',
#    'createdAt': '2022-04-18 18:20:17',
#    'updatedAt': '2022-04-18 18:20:17'},
#   'credential': {'id': '9cbff116-85b2-479d-8070-5c88af768c22',
#    'type': 'ciec',
#    'rfc': 'UTE1910213U0',
#    'status': 'valid',
#    'createdAt': '2024-08-12 16:59:34',
#    'updatedAt': '2024-08-12 16:59:57'},
#   'onboardingId': '9c016ba0-eac9-4beb-b7c7-cd57bc2187eb',
#   'createdAt': '2024-05-09 23:59:06',
#   'updatedAt': '2024-08-12 16:59:57',
#   'sample': False,
#   'tags': []},
#  {'id': '9bfab18d-f5fc-4c8c-8f7f-81d781769114',
#   'type': 'company',
#   'name': 'IMPAP SERVICIOS COMERCIALES',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'ISC150506UL1',
#    'personType': 'legal',
#    'registrationDate': '2015-05-06 00:00:00',
#    'name': 'IMPAP SERVICIOS COMERCIALES',
#    'createdAt': '2022-04-08 20:58:06',
#    'updatedAt': '2024-05-06 15:45:20'},
#   'credential': {'id': '9d2d04bc-7306-468b-8514-d5a2ec2406ed',
#    'type': 'ciec',
#    'rfc': 'ISC150506UL1',
#    'status': 'valid',
#    'createdAt': '2024-10-05 22:19:45',
#    'updatedAt': '2024-10-05 22:21:04'},
#   'onboardingId': '9bfab18d-f3ec-4580-ba01-11458ff127b2',
#   'createdAt': '2024-05-06 15:43:50',
#   'updatedAt': '2024-10-05 22:21:04',
#   'sample': False,
#   'tags': []},
#  {'id': '9b73f4d0-a563-42ef-bc72-d18ad02f02d6',
#   'type': 'company',
#   'name': 'Sociedad Yáñez S.A.B. (Ejemplo #1)',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'EAD180801SU3',
#    'personType': 'legal',
#    'registrationDate': '2018-08-01 00:00:00',
#    'name': 'Sociedad Yáñez S.A.B. (Ejemplo #1)',
#    'createdAt': '2023-08-22 17:00:27',
#    'updatedAt': '2023-08-22 17:00:27'},
#   'credential': None,
#   'onboardingId': '9bd45c46-b1f2-4266-bc14-0485a2707e11',
#   'createdAt': '2024-02-29 16:15:08',
#   'updatedAt': '2024-02-29 16:15:08',
#   'sample': True,
#   'tags': []},
#  {'id': '9b3a4173-9213-4475-b305-306d6b30bc22',
#   'type': 'company',
#   'name': 'ACEITES SUSTENTABLES DE PALMA',
#   'addedBy': None,
#   'owner': None,
#   'taxpayer': {'id': 'ASP140623IP1',
#    'personType': 'legal',
#    'registrationDate': '2014-06-23 00:00:00',
#    'name': 'ACEITES SUSTENTABLES DE PALMA',
#    'createdAt': '2023-12-19 19:29:22',
#    'updatedAt': '2023-12-19 19:32:22'},
#   'credential': {'id': '9bfb197f-3f99-477a-888c-e4a09bec6407',
#    'type': 'ciec',
#    'rfc': 'ASP140623IP1',
#    'status': 'valid',
#    'createdAt': '2024-05-06 20:34:28',
#    'updatedAt': '2024-05-06 20:34:39'},
#   'onboardingId': '9bd45c46-8bd6-4b28-bdea-bef65d544476',
#   'createdAt': '2024-01-31 23:51:25',
#   'updatedAt': '2024-05-06 20:34:40',
#   'sample': False,
#   'tags': ['Grupos de contribuyentes: Default']}]

# %% [markdown]
# ### Code to insert data into postgres

# %%
import psycopg2
from psycopg2.extras import execute_values

def insert_data_into_postgres(parsed_data, conn_params):
    """
    Inserts parsed data into the companies table in the Postgres database.

    Parameters:
    parsed_data (list): List of dictionaries, each representing a company.
    conn_params (dict): Dictionary containing Postgres connection parameters.
        Expected keys: dbname, user, password, host, port.
    """
    # Establishing the connection
    conn = psycopg2.connect(**conn_params)
    cursor = conn.cursor()

    # SQL insert query (bulk insertion using execute_values for efficiency)
    insert_query = """
    INSERT INTO entities (
        id, type, name, added_by_id, added_by_first_name, added_by_last_name, 
        added_by_email, owner_id, owner_first_name, owner_last_name, owner_email, 
        taxpayer_id, taxpayer_person_type, taxpayer_registration_date, 
        taxpayer_name, taxpayer_created_at, taxpayer_updated_at, 
        credential_id, credential_type, credential_rfc, credential_status, 
        credential_created_at, credential_updated_at, onboarding_id, 
        created_at, updated_at, sample, tags
    ) VALUES %s
    ON CONFLICT (id) DO NOTHING;  -- This prevents insertion conflicts on duplicate IDs
    """

    # Prepare the data to be inserted
    values = [
        (
            company.get("id"), 
            company.get("type"),
            company.get("name"),
            company.get("addedBy", {}).get("id") if company.get("addedBy") else None,
            company.get("addedBy", {}).get("firstName") if company.get("addedBy") else None,
            company.get("addedBy", {}).get("lastName") if company.get("addedBy") else None,
            company.get("addedBy", {}).get("email") if company.get("addedBy") else None,
            company.get("owner", {}).get("id") if company.get("owner") else None,
            company.get("owner", {}).get("firstName") if company.get("owner") else None,
            company.get("owner", {}).get("lastName") if company.get("owner") else None,
            company.get("owner", {}).get("email") if company.get("owner") else None,
            company.get("taxpayer", {}).get("id") if company.get("taxpayer") else None,
            company.get("taxpayer", {}).get("personType") if company.get("taxpayer") else None,
            company.get("taxpayer", {}).get("registrationDate") if company.get("taxpayer") else None,
            company.get("taxpayer", {}).get("name") if company.get("taxpayer") else None,
            company.get("taxpayer", {}).get("createdAt") if company.get("taxpayer") else None,
            company.get("taxpayer", {}).get("updatedAt") if company.get("taxpayer") else None,
            company.get("credential", {}).get("id") if company.get("credential") else None,
            company.get("credential", {}).get("type") if company.get("credential") else None,
            company.get("credential", {}).get("rfc") if company.get("credential") else None,
            company.get("credential", {}).get("status") if company.get("credential") else None,
            company.get("credential", {}).get("createdAt") if company.get("credential") else None,
            company.get("credential", {}).get("updatedAt") if company.get("credential") else None,
            company.get("onboardingId"),
            company.get("createdAt"),
            company.get("updatedAt"),
            company.get("sample"),
            company.get("tags")
        ) 
        for company in parsed_data
    ]

    # Perform bulk insertion using execute_values for efficiency
    try:
        execute_values(cursor, insert_query, values)
        conn.commit()
        print(f"Inserted {cursor.rowcount} rows successfully.")
    except Exception as e:
        print(f"Error during insertion: {e}")
        conn.rollback()
    finally:
        cursor.close()
        conn.close()

# Example usage:
# parsed_data = parse_json_to_dict(data)  # Assuming 'data' is the JSON data.
# conn_params = {
#     "dbname": "your_dbname",
#     "user": "your_user",
#     "password": "your_password",
#     "host": "your_host",
#     "port": "your_port"
# }
# insert_data_into_postgres(parsed_data, conn_params)
